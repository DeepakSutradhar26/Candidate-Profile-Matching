# %%
import numpy as np
import pandas as pd

# %%
career_df = pd.read_csv("career_track.csv")

# %%
career_df.head()
# Out:
#   track_id                                       career_track  \
# 0      T01  Healthcare Administration, Operations, Quality...
# 1      T02                   Healthcare Consulting & Advisory
# 2      T03  Healthcare Finance, Payer Strategy & Value-Bas...
# 3      T04      Behavioral Health & Human Services Management
# 4      T05         Public, Community & Global Health Programs
#
#                   degree_fit  \
# 0   MHA primary; MPH; MBA-HC
# 1   Career subtrack-specific
# 2  MBA-HC primary; MHA; MSHI
# 3           MPH primary; MHA
# 4   MPH primary; MHA; MBA-HC
#
#                                             keywords
# 0  Leadership evidence; ops/management interest; ...
# 1  Project-based advisory interest; client-facing...
# 2  Finance/accounting background; payer or revenu...
# 3  Mental health or SUD interest; community behav...
# 4  Community health interest; health equity langu...

# %%
degree_df = pd.read_csv("degree.csv")

# %%
degree_df.head()
# Out:
#    degree                                full_name  \
# 0     MHA          Master of Health Administration
# 1     MPH                  Master of Public Health
# 2    MSHI  Master of Science in Health Informatics
# 3  MBA-HC        MBA with Healthcare Concentration
#
#                                   focus_area
# 0  Provider operations; hospital leadership
# 1    Population health; epidemiology; policy
# 2               Health IT; data systems; EHR
# 3        Finance; strategy; entrepreneurship

# %%
subject_df = pd.read_csv("subject_cluster.csv")

# %%
subject_df.head()
# Out:
#   cluster_id           cluster_name  \
# 0         C1          Life Sciences
# 1         C2      Physical Sciences
# 2         C3     Quant & Analytical
# 3         C4    Social & Behavioral
# 4         C5  Business & Management
#
#                                             subjects   best_fit_degrees
# 0  Biology; Anatomy; Physiology; Biochemistry; Mi...          MPH; MSHI
# 1  Physics; Chemistry; Environmental Chemistry; E...                MPH
# 2  Statistics; Biostatistics; Calculus; Data Scie...  MPH; MSHI; MBA-HC
# 3  Psychology; Sociology; Social Work; Community ...           MPH; MHA
# 4  Accounting; Finance; Economics; Marketing; Man...        MBA-HC; MHA

# %%
test_df = pd.read_csv("test.csv")

# %%
test_df.head()
# Out:
#                         id                     degree  \
# 0      Sample_FreshGrad_01                        BDS
# 1  Sample_MPH_Community_01               BA Sociology
# 2    Sample_MBA_Finance_01  BCom Accounting & Finance
# 3      Sample_MSHI_Tech_01     BTech Computer Science
# 4        Sample_MHA_LTC_01                BSc Nursing
#
#                                   university  gpa    year  \
# 0  Maharashtra University of Health Sciences  NaN     NaN
# 1                       University of Mumbai  3.5  2022.0
# 2                    Symbiosis International  3.7  2020.0
# 3                                VIT Vellore  3.6  2021.0
# 4                                AIIMS Delhi  3.8  2019.0
#
#                                             subjects  experience_years  \
# 0  anatomy; physiology; biochemistry; pathology; ...                 0
# 1  sociology; community development; social resea...                 1
# ...
